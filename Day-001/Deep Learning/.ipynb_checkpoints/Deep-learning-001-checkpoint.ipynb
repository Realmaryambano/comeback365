# %%
pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__) # asks TensorFlow for its installed version and prints it.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__) # asks TensorFlow for its installed version and prints it.
#
# ModuleNotFoundError: No module named 'tensorflow'
